# %% [markdown]
# ## Herzlich willkommen zum Workshop "Einführung ins Programmieren!" 💻
#
# Wir lernen heute ein paar Basics im Programmieren kennen und verwenden dafür die Programmiersprache Python 🐍
#
# ---
#
# Python ist eine Sprache, die es seit den Neunziger Jahren gibt und die sehr beliebt ist, weil sie universell einsetzbar ist und recht leicht zu lernen ist. Die Sprache arbeitet mit sogenannten Modulen, die eigene Funktionen mitbringen. Solche Module müssen erst in Python installiert und dann importiert werden
#
# Fangen wir also an, das Modul "ColabTurtlePlus" zu installieren:

# %%
# !pip3 install ColabTurtlePlus

# %% [markdown]
# Sehr gut! Nun, da das Modul installiert ist, können wir es importieren. Dazu verwenden wir die Funktion
#
# ```
# import ... as
# ```
# Damit sagen wir Python, dass wir das Modul Colabturtle installieren wollen, und geben diesem Modul auch einen Namen: "turtle".
# Anschließend müssen wir das Modul turtle noch initialisieren, also starten, damit es direkt in diesem Notizbuch ausgeführt wird.

# %%
import ColabTurtlePlus.Turtle as turtle
turtle.clearscreen()
turtle.initializeTurtle(window = (800,600), mode = "standard") 
turtle.turtlesize(stretch_wid = 1.5, stretch_len = 1.5)
turtle.shape("turtle")

# %% [markdown]
# Da ist sie auch schon, unsere 🐢
#
# Wir können nun anfangen, die Schildkröte etwas auf dem Bildschirm zu bewegen. Lassen wir sie erst mal ein paar Schritte vorwärts laufen:

# %%
turtle.forward(80)

# %% [markdown]
# Du kannst eine Zeile Code beliebig oft ausführen und die Schildkröte läuft dann immer weiter in die angegebene Richtung, z.B. vorwärts. Natürlich kannst du die Zahl der Schritte auch verändern.
#
# Lassen wir die Schildkröte nun links abbiegen:

# %%
turtle.left(90)

# %% [markdown]
# Wir geben hier einen Winkel in Grad an, also z.B. 90 Grad nach links. Probier doch mal verschiedene Winkel aus. Wie läuft die Schildkröte nach rechts?

# %%
turtle.right(35)

# %%
turtle.forward(55)

# %% [markdown]
# ▶ Hast du eine Idee, wie die Schildkröte rückwärts läuft?
#
# Wir können uns auch die Position unserer Schildkröte ausgeben lassen. Dann bekommen wir Zahlen zurück, wie in einem Koordinatensystem oder auf einer Karte, die die genaue Position der Schildkröte angeben:

# %%
turtle.position()

# %% [markdown]
# Natürlich können wir sie auch auf eine bestimmte Position auf der Karte schicken. Auch das funktioniert wie in einem Koordinatensystem: Wir geben erst eine Zahl für die waagerechte Richtung, die x-Koordinate, und dann für die senkrechte Richtung, also die y-Koordinate, an:

# %%
turtle.clearscreen()
turtle.shape("turtle")
turtle.goto(-200, -60)

# %% [markdown]
# Huch, jetzt ist sie ganz schön weit weg. Holen wir die Schildkröte erst mal zurück an ihren Aussprungsort. Benutze dafür die Funktion:
#
# ```
# turtle.home()
# ```

# %%
# Schreibe die Funktion in diese Zelle

# %% [markdown]
# Wir können auch die bisherigen Schritte löschen, sodass die Schildkröte wieder bei null anfängt:

# %%
turtle.home()
turtle.clear()

# %% [markdown]
# Eigentlich sind Schildkröten ja gar nicht schwarz. Lass uns ihr eine Farbe geben. Das machst du mit folgender Funktion und einem englischen Wort für eine Farbe deiner Wahl. Ergänze dazu das Farbwort zwischen den Anführungszeichen:

# %%
turtle.color(" ")

# %% [markdown]
# Natürlich können wir die Farbe und Breite der Linien separat anpassen. Dies machst du mit den Funktionen
#
# ```
# turtle.pencolor(" ")
# turtle.width(10)
# ```
# Gib deiner Schildkröte eine separate Farbe für die Linien, die sie malt, und lass sie dann ein **Rechteck** zeichnen, indem du die Funktionen für Richtungen sowie vorwärts und rückwärts verwendest:
#
# ```
# turtle.forward()
# turtle.backward()
# turtle.right
# turtle.left
# ```
#
# Am Ende sollte es etwa so aussehen:
#
# ![Bildschirmfoto 2022-04-25 um 15.46.17.png](data:image/png;base64,...)
#
#
# Viel Erfolg!

# %%
# Starte in dieser Zelle mit deinem Code
turtle.clearscreen()
turtle.shape("turtle")

# %% [markdown]
# Toll! Jetzt kennst du schon einige grundlegende Funktionen zum Programmieren.
#
# Unsere Schildkröte kann aber nicht nur in angegebene Richtungen laufen, sondern kennt bestimmte Formen sogar schon selbst, z.B. Dreicke, Rechtecke, Fünfecke oder auch Kreise.
#
# Lassen wir unsere Schildkröte mal ein Dreieck zeichnen:

# %%
turtle.clearscreen()
turtle.shape("turtle")
turtle.regularPolygon(3, 150)

# %% [markdown]
# Dieses Dreieck können wir auch füllen! Verwende dafür die Funktionen
# ```
# turtle.begin_fill()
# ```
# und
# ```
# turtle.end_fill()
# ```
# vor und nach dem Dreieck.

# %%
# Sage turtle erst, dass der fill beginnt, zeichne dann deine Figure, und sage turtle abschließend, dass der fill vorbei ist:
turtle.clearscreen()
turtle.shape("turtle")

# %% [markdown]
# Kannst du auch andere Form als ein Dreieck zeichnen und die Farbe der Füllung ändern?

# %%
# Probiere es hier aus:
turtle.clearscreen()
turtle.shape("turtle")

# %% [markdown]
# Super! Zum Abschluss schauen wir uns noch die Kreise an.
#
# Die Schildkröte kennt auch Kreise als feste Formen. Dazu verwenden wir die Funktion:
# ```
# turtle.circle(100)
# ```
#
# Die Zahl gibt den Radius des Kreises an, also wie groß der Kreis sein soll. Probier verschiedene Größen aus:

# %%
turtle.clearscreen()
turtle.shape("turtle")
turtle.circle(80)

# %% [markdown]
# Wir können der Schildkröte außerdem mitteilen, dass sie keinen vollen Kreis, sondern zum Beispiel nur ein Viertel oder einen halben Kreis zeichnen soll. Dafür nimmt unsere Kreisfuntion ein zweites Argument:
#
# ```
# turtle.circle(100, 180)
# ```

# %%
turtle.clearscreen()
turtle.shape("turtle")
turtle.circle(100, 180)

# %% [markdown]
# Wollen wir nicht immer einen durchgezogenen Strich erhalten, können wir mit dem Befehl ```turtle.up()``` den Stift abheben und wieder neu aufsetzen über die Anweisung ```turtle.down()```:

# %%
turtle.clearscreen()
turtle.shape("turtle")
turtle.color('yellow')
turtle.width(10)
turtle.circle(100)
turtle.up()
turtle.color('orange')
turtle.forward(150)
turtle.down()
turtle.circle(100)

# %% [markdown]
# ▶ Letzte Challenge für heute: Kannst du eines der folgenden Bilder mithilfe von turtle zeichnen? Verwende dafür die Funktionen zu Kreisen, Farben und den Richtungen von turtle!
#
# ![Bildschirmfoto 2022-04-25 um 19.20.25.png](data:image/png;base64,...)![Bildschirmfoto 2022-04-25 um 18.39.22.png](data:image/png;base64,...)
#
# Viel Spaß!!
